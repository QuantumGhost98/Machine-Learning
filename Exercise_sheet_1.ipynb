# %% [markdown]
# # Exercise Sheet 1: Probability and Distribution
#
# This repository contains **Exercise Sheet 1**, focusing on foundational concepts of **Probability** and **Distribution**, with practical applications in problem-solving and statistical analysis.
#
# ## Topics Covered
#
# ### 1. Probability
# Explore the fundamental concepts of joint and marginal distributions, probability tables, and their applications in everyday scenarios.
# **Key Skills:**
# - Understanding and calculating probabilities.
# - Applying joint and marginal distributions to solve problems.
#
# ### 2. Distribution
# Dive into the basics of statistical distributions, understanding their behavior, and how they apply to real-world examples.
# **Key Skills:**
# - Working with probability distributions.
# - Interpreting data and applying statistical models.
#
# ## Purpose
# This exercise sheet is designed to build a strong foundation in probability and distribution concepts, which are essential for understanding more advanced topics in machine learning and data analysis.

# %% [markdown]
# ## Chapter 1: Probabilities

# %% [markdown]
# ### 1.1 Cats and Dogs
#
# *Topics: joined and marginal distributions, probability tables*
#
# My neighbor has two pets. Assume that the choice to own a cat or a dog is like a coin flip: the two options are mutually exclusive and exhaustive, per pet.
#
# 1. Which possibility is the most likely, a priori, given the assumptions above: two cats, two dogs, or one cat and one dog?
# 2. Suppose I ask my neighbor if he has any dogs, and he says yes. What is the probability that one pet is a cat?
# 3. Suppose that instead I see one of his pets run by in his house and its a dog. What is the probability that the other pet is a cat?

# %% [markdown]
# 1. The two cats or do probability is $P(CC)= P(DD)= 0.25 $. Instead, $P(CD)+P(DC)=0.5$. Then, it is more likely one can and one dog.
# 2. The probability is $P(DC)+P(CD)= 2/3 $. It is a renormalized probability.
# 3. I can use the B.Theorem. $P(C|D)= \frac{P(D|C)P(C)}{P(D)}= 1/2$

# %%
from IPython.display import IFrame

# Specify the URL of the PDF file
url = 'https://drive.google.com/file/d/1lD_5MHBn3jphcZn-7I6SGW3ZDpUiNSLr/view?usp=share_link'

# Extract the file ID from the URL
file_id = url.split('/')[-2]

# Construct the embedded link
embedded_link = f'https://drive.google.com/file/d/{file_id}/preview'

# Display the PDF file
IFrame(src=embedded_link, width='100%', height='500px')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="https://drive.google.com/file/d/1lD_5MHBn3jphcZn-7I6SGW3ZDpUiNSLr/preview"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 1.2 Monty Hall Problem
#
# *Topics: joined and marginal distributions, probability tables*
#
# On a game show, a contestant is told the following rules:
#
#
# > There are three doors, labelled 1, 2, 3. A single prize has been hidden behind one of them. You get to select one door. Initially your chosen door will not be opened. Instead, the gameshow host will open one of the other two doors, and *he will do so in such a way as not to reveal the prize.* For example, if you first choose door 1, he will then open one of doors 2 and 3, and it is guaranteed that he will choose which one to open so that the prize will not be revealed. At this point, you will be given a fresh choice of door: you can either stick with your first choice, or you can switch to the other closed door. All the doors will then be opened and you will receive whatever is behind your final choice of door.
#
# Imagine that the contestant chooses door 1 first; then the gameshow host opens door 3, revealing nothing
# behind the door, as promised. Should the contestant (a) stick with door 1, or (b) switch to door 2, or (c) does it make no difference? You may assume that initially, the prize is equally likely to be behind any of the 3 doors.

# %% [markdown]
# At the beginning, if the contenstant chooses the first door, he has $p(1)= 1/3$. The others two doors has same probability. Then, when the host open the door 2, we have $p(2)=0$. If the constanst decides to stick with this decisiion, he has that $p(1)=1/3$ and $p(3)=2/3$. So, he has less probability to win if he sticks with his decision.

# %%
from IPython.display import IFrame

# Specify the URL of the PDF file
url = 'https://drive.google.com/file/d/1DqFNyDClSXNxifvVT5-DTK9pQb4A0IWh/view?usp=sharing'

# Extract the file ID from the URL
file_id = url.split('/')[-2]

# Construct the embedded link
embedded_link = f'https://drive.google.com/file/d/{file_id}/preview'

# Display the PDF file
IFrame(src=embedded_link, width='100%', height='500px')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="https://drive.google.com/file/d/1DqFNyDClSXNxifvVT5-DTK9pQb4A0IWh/preview"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 1.4 Particle Identification
#
# *Topic: Bayes theorem*
#
# A beam of particles consists of mainly photons with a small fraction of $10^{-4}$ electrons. The particles of the beam pass through a detector with two detection layers and can create a signal in either of the two layers. One particle passes through the detector at a time. The probabilities of either an electron $e$ or a photon $\gamma$ creating signals in 0, 1 or 2 layers are:
#
# $p(0|e) = 0.001 \quad \text{and} \quad p(0|\gamma) = 0.99899\\
# p(1|e) = 0.010 \quad \text{and} \quad p(1|\gamma) = 0.001 \\
# p(2|e) = 0.989 \quad \text{and} \quad p(2|\gamma) = 10^{-5}$
#
# 1. The particles of the beam come in to the detector one-by-one. What's the probability that the incoming particle is an electron?
#
# 2. A signal is detected in only one layer. What is the probability for the particle to be a photon?
#
# 3. What is the probability for the particle to be an electron given a detected signal in both layers?

# %% [markdown]
# 1. The $P(E)=10^{-4}$.
# 2. Using the B. Theorem we have $P(\gamma|1)=\frac{P(1|\gamma)(1-P(e)}{P(1)}= \frac {P(1|\gamma)1(1-P(e))}{P(1|\gamma)1(1-P(e))+P(1|e)P(e)}=0.99$
# 3. Using the B. Theorem we have $P(e|2)= \frac{P(2|e)P(e)}{P(2|e)P(e)+P(2|\gamma)(1-P(e))}=0.989$

# %% [markdown]
# ### 1.5 Sampling from a Probabilistic Model
#
# *Topic: frequentist probabilities*
#
# Let's say we have a probabilistic model with
#
# | X | p(X) |
# |------|------|
# | Sun (0)   | 0.2 |
# | Rain (1)  | 0.3 |
# | Snow (2)  | 0.5 |
#
# a. Write a sampler that randomly samples from $p(X)$ values X = 0, 1, 2. In your solution, you are allowed to use the function `numpy.random.random()` but other than this, do not use any other imported functions.

# %%
import numpy as np
import matplotlib.pyplot as plt

def return_random_sample():
    value = 0
    random_value = np.random.random()
    if random_value < 0.2:
        value = 0
    elif random_value <0.5:
        value = 1
    elif random_value <1:
        value = 2
    return value 

return_random_sample()
# Out:
# 1

# %% [markdown]
# b. Make a normalized histogram of the resulting values. Try a few values for the number of samples. Approximately how many samples do you require to get a qualitatively good (say, within 10%) agreement with the above probabilities?

# %%
list_values = np.array([return_random_sample() for i in range(1000)])

plt.hist(list_values, density=True, bins=range(4))
plt.ylabel('P(x)')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ### 1.6 Conditional Probabilities
#
# *Topics: frequentist probabilities, conditional probabilities*
#
# Consider the probability table:
#
# | X | Y | p(X,Y) |
# |------|------| ----- |
# | Hot (0)   | Sun (0) | 0.4 |
# | Hot (0) | Rain (1) | 0.1 |
# | Cold (1)  | Sun (0) | 0.2 |
# | Cold (1)  | Rain (1) | 0.3 |
#
#
#
# a. Implement a sampling algorithm that samples $(X, Y)$ pairs.

# %%
def return_random_sample_joint():
    prob_value = np.random.random()
    x_value = 0
    y_value = 0
    if prob_value < 0.4:
        x_value = 0
        y_value =0
    elif prob_value < 0.5:
        x_value = 0
        y_value =1
    elif prob_value < 0.7:
        x_value=1
        y_value = 0
    elif prob_value <1:
        x_value =1
        y_value =1
    return [x_value,y_value]

# %% [markdown]
# b. Generate samples from $p(Y| X = 0)$ by removing ("rejecting") some samples generated by your above sampling algorithm. Use these to generate a histogram for the conditional distribution $p(Y| X=0)$.

# %%
list_values_new=[]
for j in range(1000):
    if return_random_sample_joint() == [0,0]:
        list_values_new.append(0)
    if return_random_sample_joint() == [0,1]:
        list_values_new.append(1)

plt.hist(list_values_new, density=True, bins=range(3))
plt.ylabel('P(x) Marg')
plt.xlabel('x')
plt.show()

# %% [markdown]
# ## Chapter 2: Distributions

# %% [markdown]
# ### 2.1 Convolution of two normal distributions
#
# *Topics: normal distributions, variance, mean, combining distributions, sums of random variables*
#
# This exercise will demonstrate useful properties of normal distributions. A normal distribution $\mathcal{N}(x|\mu, \sigma)$ is completely defined by its mean $\mu$ and its standard deviation $\sigma$. As shown in the previous exercise, its PDF can be written as
# $$ \mathcal{N}(x|\mu, \sigma) = \frac{1}{\sqrt{2 \pi}\sigma} \exp\left( \frac{-(x-\mu)^2}{2 \sigma^2} \right) \, .$$
#
# #### 2.1.1 (1 point)
# Create two datasets $\vec{x} = \{x_1, x_2, \dots, x_N\}$ and $\vec{y} = \{y_1, y_2, \dots, y_N\}$ by drawing randomly from the PDF of the normal distribution. For $\vec{x}$ draw from $\mathcal{N}(x|\mu=2, \sigma=1)$ and for $\vec{y}$ draw from $\mathcal{N}(y|\mu=4, \sigma=2)$. In order to have enough statistics, let $N = 10000$. Vizualize $\vec{x}$ and $\vec{y}$ in histograms with 32 bins from -2 to 14.
#
# **Hint**: You can use `numpy.random.normal()` to draw $x$ values randomly from $\mathcal{N}(x|\mu, \sigma)$. Use `matplotlib.pyplot` to plot the datasets in a histogram.

# %%
N = 1000
x_dataset = np.random.normal(2,1,N)
y_dataset = np.random.normal(4,2,N)

# Create histogram for the first data set
plt.hist(x_dataset, bins=32, range=(-2, 14), alpha=0.5, color='blue', label='first data set',density=True)

# Create histogram for the second data set
plt.hist(y_dataset, bins=32, range=(-2, 14), alpha=0.5, color='red', label='second data set',density=True)

# Set labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of first and second data set')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### 2.1.2
# Create a third dataset $\vec{z} = \{z_1, z_2, \dots, z_N\}$ where $z_i$ is the sum of two random numbers $x_i$ and $y_i$ that are drawn from $\mathcal{N}(x|\mu=2, \sigma=1)$ and $\mathcal{N}(x|\mu=4, \sigma=2)$, respectively. Plot the dataset. What do you observe? What does the distribution look like? How is its mean related to the two initial normal PDFs?

# %%
z_dataset = x_dataset + y_dataset

# Create histogram for the first data set
plt.hist(x_dataset, bins=32, range=(-2, 14), alpha=0.5, color='blue', label='first data set',density=True)

# Create histogram for the second data set
plt.hist(y_dataset, bins=32, range=(-2, 14), alpha=0.5, color='red', label='second data set',density=True)

# Create histogram for the second data set
plt.hist(z_dataset, bins=32, range=(-2, 14), alpha=0.5, color='yellow', label='third data set',density=True)

# Set labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of first and second data set')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# #### 2.1.3
# Calculate the variance of the third dataset. Do you find a relation to the variances of $\vec{x}$ and $\vec{y}$?

# %%
mean = np.mean(z_dataset)
variance = np.var(z_dataset)

display(mean)
display(variance)
# Out:
# 6.037289854177658
# 5.265581909617577

# %% [markdown]
# #### 2.1.4
# Mathematically, the PDF of a sum of two random variables is the convolution of their individual PDFs (do you understand why?). Let's call their PDFs $f(x)$ and $g(x)$, then the convolution is defined as
#
# $$ (f \circledast g)(x) = \int_{-\infty}^{\infty} f(\tau) g(x - \tau) d\tau \, .$$
#
# Program this convolution yourself for the two normal distributions $\mathcal{N}(x|\mu=2, \sigma=1)$ and $\mathcal{N}(x|\mu=4, \sigma=2)$ and show that you can recover the same connections seen already for the sets $\vec{x}$, $\vec{y}$ and $\vec{z}$.
#
# **Hint**: You are **not** allowed to use a predefined convolution function. Approximate the integral by a sum over small elements with width $\Delta \tau$.

# %%
def convolution(f, g, x, delta):
    N = len(x)
    conv = np.zeros(N)
    for i in range(N):
        for j in range(N):
            if i-j >= 0:  # Ensure non-negative index
                conv[i] += f[j] * g[i-j] * delta
    return conv

x = np.linspace(-10,10, 100)
delta = x[1]-x[0]

# %% [markdown]
# ### 2.2 Gauss from Poisson
#
# *Topics: connections between normal and Poisson distribution*
#
# Consider a Poisson distribution given as $P(x) = \frac{\lambda^x}{x!}\exp(-\lambda)$. Show that in the limit of large $\lambda$, $P(x)$ can be approximated by a normal distribution.
#
# **Hint**: Consider taking the natural logarithm of $P(x)$. The following two relations can also be of use:
# 1. Stirling formula: $x! \approx x^x \exp(-x) \sqrt{2\pi x}$ (for large $x$)
# 2. $\ln(1+\varepsilon) \approx \epsilon - \epsilon^2/2 + \epsilon^3/3 - \dots$

# %%
from IPython.display import IFrame

# Specify the URL of the PDF file
url = 'https://drive.google.com/file/d/1SRIEGr5JLkdnEAFlMzena5UtYXxguQnW/view?usp=sharing'

# Extract the file ID from the URL
file_id = url.split('/')[-2]

# Construct the embedded link
embedded_link = f'https://drive.google.com/file/d/{file_id}/preview'

# Display the PDF file
IFrame(src=embedded_link, width='100%', height='500px')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="https://drive.google.com/file/d/1SRIEGr5JLkdnEAFlMzena5UtYXxguQnW/preview"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### 2.3 Normal distributions in the real world
#
# *Topics: normal distributions, KL-divergence, mean, variance*
#
# Normal distributions can frequently be found in nature. Below you can find an example code that downloads a dataset of human height measurements.
# - Plot the height distribution. Does it look like a normal distribution to you? Can you think of reasons why not? Adjust the data selection such that it becomes closer to a normal distribution.
# - After adjusting the data selection, calculate the mean and variance of the height distribution.
# - Compare the data with a normal distribution that has the same mean and variance using the KL divergence ($p$ should be your "fitted" normal distribution, and $q$ should correspond to the data):
#
# $$D_{KL}(q|| p) = \int dx \, q(x) \ln \frac{q(x)}{p(x)} \, .$$
#
# **Hint:** We recommend to use the `scipy.stats.entropy` function to calculate the KL-divergence.
# - Can you think of a reason why the distribution looks approximately normal? Also give an argument why it could be that it's not exactly a normal distribution.

# %%
# !pip install wget
# Out:
# Requirement already satisfied: wget in /Users/PietroPaolo/opt/anaconda3/envs/progLab/lib/python3.9/site-packages (3.2)

# %%
import wget
import pandas as pd
url = 'https://www.dropbox.com/s/045pre7g6hdb0r0/galton-stata11.tab?dl=1'
filename = wget.download(url, out='.')
df = pd.read_csv('galton-stata11.tab', delim_whitespace=True)
data = df['height']

# %%
plt.hist(data)

# Set labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')


# Show the plot
plt.show()

# %% [markdown]
# I can fix it making a two difference set between male and female. The dataset was mixed, and this makes the distribution "less gaussian".

# %%
# DataFrame for males
df_males = df[df['gender'] == 'M']

# DataFrame for females
df_females = df[df['gender'] == 'F']

# Display the DataFrames
display(df_males)
display(df_females)
# Out:
#     family  father  mother gender  height  kids  male  female
# 0        1    78.5    67.0      M    73.2     4   1.0     0.0
# 4        2    75.5    66.5      M    73.5     4   1.0     0.0
# 5        2    75.5    66.5      M    72.5     4   1.0     0.0
# 8        3    75.0    64.0      M    71.0     2   1.0     0.0
# 10       4    75.0    64.0      M    70.5     5   1.0     0.0
# ..     ...     ...     ...    ...     ...   ...   ...     ...
# 890   136A    68.5    65.0      M    72.0     8   1.0     0.0
# 891   136A    68.5    65.0      M    70.5     8   1.0     0.0
# 892   136A    68.5    65.0      M    68.7     8   1.0     0.0
# 893   136A    68.5    65.0      M    68.5     8   1.0     0.0
# 894   136A    68.5    65.0      M    67.7     8   1.0     0.0
#
# [465 rows x 8 columns]
#     family  father  mother gender  height  kids  male  female
# 1        1    78.5    67.0      F    69.2     4   0.0     1.0
# 2        1    78.5    67.0      F    69.0     4   0.0     1.0
# 3        1    78.5    67.0      F    69.0     4   0.0     1.0
# 6        2    75.5    66.5      F    65.5     4   0.0     1.0
# 7        2    75.5    66.5      F    65.5     4   0.0     1.0
# ..     ...     ...     ...    ...     ...   ...   ...     ...
# 887    203    62.0    66.0      F    61.0     3   0.0     1.0
# 889    204    62.5    63.0      F    57.0     2   0.0     1.0
# 895   136A    68.5    65.0      F    64.0     8   0.0     1.0
# 896   136A    68.5    65.0      F    63.5     8   0.0     1.0
# 897   136A    68.5    65.0      F    63.0     8   0.0     1.0
#
# [433 rows x 8 columns]

# %%
plt.hist(df_males['height'])

# Set labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')


# Show the plot
plt.show()

mean_male = np.mean(df_males['height'])
var_male = np.var(df_males['height'])

# %%
plt.hist(df_females['height'])

# Set labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')


# Show the plot
plt.show()

mean_female = np.mean(df_females['height'])
var_female = np.var(df_females['height'])

# %%
data_point_male = np.linspace(min(df_males['height']), max(df_males['height']), len(df_males['height']) )
data_point_female = np.linspace(min(df_females['height']), max(df_females['height']), len(df_females['height']) )

def normal_distribution(x, mu, sigma):
    f= 1 / (sigma * np.sqrt(2 * np.pi)) * np.exp(-0.5 * ((x - mu) / sigma)**2)
    return f


gaussian_male = normal_distribution(data_point_male, mean_male, var_male)
gaussian_female = normal_distribution(data_point_female, mean_female, var_female)

# %%
import scipy
#now, that i have my fitted data and original data, i can compute the entropy
kl_entropy_male= scipy.stats.entropy(gaussian_male,df_males['height'],base=None, axis=0)
print(kl_entropy_male, "KL-Entropy Male")

kl_entropy_female= scipy.stats.entropy(gaussian_female,df_females['height'],base=None, axis=0)
print(kl_entropy_male, "KL-Entropy Male")
# Out:
# 0.03561354889562665 KL-Entropy Male
# 0.03561354889562665 KL-Entropy Male

# %% [markdown]
# ### 2.4 Marginal normal distributions
#
# *Topics: multivariate normal & marginal distributions*
#
# Consider a multivariate Gaussian of the form
# $$P(\mathbf{x}) = \mathcal{N}(\mathbf{x}|\mathbf{\mu}, \mathbf{\Sigma}) = \frac{1}{(2\pi)^{D/2} |\mathbf{\Sigma}|^{1/2}} \exp\left(-\frac{1}{2} (\mathbf{x}-\boldsymbol{\mu})^{T} \mathbf{\Sigma}^{-1}(\mathbf{x}-\boldsymbol{\mu})\right) \, ,$$
#
# where $\mathbf{x}$ and $\boldsymbol{\mu}$ are vectors with $D$ entries and $\mathbf{\Sigma}$ is a $D \times D$ covariance matrix. $|\mathbf{\Sigma}|$ is the determinant of this matrix.

# %% [markdown]
# #### 2.4.1 (2 points)
# Consider the case where $D = 2$. Use the following three sets of ($\boldsymbol{\mu}$, $\mathbf{\Sigma}$) to create 2D contour- and 3D surface plots of the corresponding PDFs (with arbitrary contour levels)
#
# $$ \boldsymbol{\mu_1} = \begin{pmatrix} 5 \\ 5 \end{pmatrix} ~ \mathbf{\Sigma_1} = \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix} \, ,$$
#
# $$ \boldsymbol{\mu_2} = \begin{pmatrix} 5 \\ 5 \end{pmatrix} ~ \mathbf{\Sigma_2} = \begin{pmatrix} 1 & -0.5 \\ -0.5 & 1 \end{pmatrix} \, ,$$
#
# $$ \boldsymbol{\mu_3} = \begin{pmatrix} 5 \\ 5 \end{pmatrix} ~ \mathbf{\Sigma_3} = \begin{pmatrix} 1 & 0.7 \\ 0.7 & 1 \end{pmatrix} \, .$$
#
# Implement the multivariate Gaussian yourself using numpy matrix multiplication.

# %%
def mvgauss(x, mu, sigma,D):
    denominator  = (2 * np.pi)**(D/2) * np.sqrt(np.linalg.det(sigma))
    numerator  = np.exp(-1/2 * np.sum(np.matmul((x-mu), np.linalg.inv(sigma)) * (x-mu), axis =-1))
    #numerator = np.exp(-0.5 * np.sum(np.matmul((x - mu), np.linalg.inv(sigma)) * (x - mu), axis=-1))
    #numerator = np.exp(-0.5 * np.sum(np.matmul((x - mu), np.linalg.inv(sigma)) * (x - mu), axis=-1))
    f = numerator / denominator
    return f

mean = np.array([5, 5])

sigma_1 = np.array([[1,0] , [0,1]])
sigma_2 = np.array([[1,-0.5] , [-0.5,1]])
sigma_3 = np.array([[1,0.7] , [0.7,1]])

# Generate a grid of points
x, y = np.meshgrid(np.linspace(2, 8, 100), np.linspace(2, 8, 100))
grid = np.dstack((x, y))

distribution_1 = mvgauss(grid, mean, sigma_1,2)

distribution_2 = mvgauss(grid, mean, sigma_2,2)

distribution_3 = mvgauss(grid, mean, sigma_3,2)

# %%
# Creating contour plot for distribution_1
plt.figure()
plt.contour(distribution_1, levels=10)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Contour Plot of Multivariate Gaussian Distribution with epsilon1')
plt.show()

# %%
# Creating contour plot for distribution_1
plt.figure()
plt.contour(distribution_2, levels=10)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Contour Plot of Multivariate Gaussian Distribution with epsilon2')
plt.show()

# %%
# Creating contour plot for distribution_1
plt.figure()
plt.contour(distribution_3, levels=10)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Contour Plot of Multivariate Gaussian Distribution with epsilon3')
plt.show()

# %%
# Assuming X, Y, and distribution_1 are already computed as before
# X and Y are the meshgrid, and distribution_1 is the Gaussian distribution

# Create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface using X, Y (from meshgrid), and the Gaussian distribution (distribution_1) as Z values
ax.plot_surface(x, y, distribution_1, cmap='viridis')

# Labels and title
ax.set_title("3D Surface Plot of Multivariate Gaussian")
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Probability Density')

# Show the plot
plt.show()

# %%
# Assuming X, Y, and distribution_1 are already computed as before
# X and Y are the meshgrid, and distribution_1 is the Gaussian distribution

# Create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface using X, Y (from meshgrid), and the Gaussian distribution (distribution_1) as Z values
ax.plot_surface(x, y, distribution_2, cmap='viridis')

# Labels and title
ax.set_title("3D Surface Plot of Multivariate Gaussian")
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Probability Density')

# Show the plot
plt.show()

# %%
# Assuming X, Y, and distribution_1 are already computed as before
# X and Y are the meshgrid, and distribution_1 is the Gaussian distribution

# Create a 3D figure
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface using X, Y (from meshgrid), and the Gaussian distribution (distribution_1) as Z values
ax.plot_surface(x, y, distribution_3, cmap='viridis')

# Labels and title
ax.set_title("3D Surface Plot of Multivariate Gaussian")
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Probability Density')

# Show the plot
plt.show()

# %% [markdown]
# #### 2.4.2
# The marginal distribution of a multivariate Gaussian is defined as
#
# $$ P(\mathbf{x}_i) = \int P(\mathbf{x}_i, \mathbf{x}_j) \, d\mathbf{x}_j \, .$$
#
# Calculate the marginal distributions for the three multivariate Gaussians from above along the $x$ and $y$ axis. First do the calculation for one of the marginals by hand, and then use this to argue the answer for the other five marginals. Confirm your results using the `margins()` function from `scipy.stats.contingency`. How do the different marginal distributions compare?

# %%
from IPython.display import IFrame

# Specify the URL of the PDF file
url = 'https://drive.google.com/file/d/1z-XAKz1CjCLIx-Z2tKFddGLjeXCTt6n1/view?usp=share_link'

# Extract the file ID from the URL
file_id = url.split('/')[-2]

# Construct the embedded link
embedded_link = f'https://drive.google.com/file/d/{file_id}/preview'

# Display the PDF file
IFrame(src=embedded_link, width='100%', height='500px')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="https://drive.google.com/file/d/1z-XAKz1CjCLIx-Z2tKFddGLjeXCTt6n1/preview"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from scipy.stats.contingency import margins
# Put your solution here

margins_1_x, margins_1_y = margins(distribution_1)

# Plotting the marginal distributions
plt.figure(figsize=(10, 5))

# Plot marginal distribution for x
plt.subplot(1, 2, 1)
plt.plot(np.linspace(2, 8, 100), margins_1_x.flatten())
plt.title('Marginal Distribution of X')
plt.xlabel('X')
plt.ylabel('Density')

# Plot marginal distribution for y
plt.subplot(1, 2, 2)
plt.plot(np.linspace(2, 8, 100), margins_1_y.flatten())
plt.title('Marginal Distribution of Y')
plt.xlabel('Y')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
margins_2_x, margins_2_y = margins(distribution_2)

# Plotting the marginal distributions
plt.figure(figsize=(10, 5))

# Plot marginal distribution for x
plt.subplot(1, 2, 1)
plt.plot(np.linspace(2, 8, 100), margins_2_x.flatten())
plt.title('Marginal Distribution of X')
plt.xlabel('X')
plt.ylabel('Density')

# Plot marginal distribution for y
plt.subplot(1, 2, 2)
plt.plot(np.linspace(2, 8, 100), margins_2_y.flatten())
plt.title('Marginal Distribution of Y')
plt.xlabel('Y')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# %%
margins_3_x, margins_3_y = margins(distribution_3)

# Plotting the marginal distributions
plt.figure(figsize=(10, 5))

# Plot marginal distribution for x
plt.subplot(1, 2, 1)
plt.plot(np.linspace(2, 8, 100), margins_3_x.flatten())
plt.title('Marginal Distribution of X')
plt.xlabel('X')
plt.ylabel('Density')

# Plot marginal distribution for y
plt.subplot(1, 2, 2)
plt.plot(np.linspace(2, 8, 100), margins_3_y.flatten())
plt.title('Marginal Distribution of Y')
plt.xlabel('Y')
plt.ylabel('Density')

plt.tight_layout()
plt.show()
